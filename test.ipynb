# %%
from handler import *
from preprocessing import *

# %%
path = "G:/DEPI/Depi_Amit_AI_BNS3/Tasks/DataBase/Data_processing_workshop/train_test.csv"
df = read_csv(path)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0     3.0
# 1              2         1     1.0
# 2              3         1     3.0
# 3              4         1     NaN
# 4              5         0     3.0
# ..           ...       ...     ...
# 886          887         0     2.0
# 887          888         1     1.0
# 888          889         0     3.0
# 889          890         1     1.0
# 890          891         0     3.0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = read_csv("G:/DEPI/Depi_Amit_AI_BNS3/Sources/Health_Predictive_Analysis/Data_files/cardio_train.csv",";")
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
import plotly.subplots as sp
import plotly.graph_objects as go
import plotly.express as px

# %%
px.pie(df,names='gender',title='<b> gender Distribution</b>',color_discrete_sequence=px.colors.qualitative.Pastel,hole=0.4)

# %%
save_csv(df,"G:/DEPI/Depi_Amit_AI_BNS3/Sources/Health_Predictive_Analysis/Data_files/data")
# Out:
# csv saved!
